# %% [markdown]
# 1.In the below elements which of them are values or an expression? eg:-
# values can be integer or string and expressions will be mathematical
# operators.
#
# -
#
# 'hello' -87.8
#
# -
#
# /
#
# -
#
# 6
#
# => Values- ‘hello’, -87.8, 6 Expression- \*, - , / , +
#
# 2.What is the difference between string and variable?
#
# => string is a data type and variable is like a container (a=4),here a
# is variable which store the value 4.
#
# 3.Describe three different data types.
#
# => String,Integer,Float
#
# 4.What is an expression made up of? What do all expressions do?
#
# Ans1: expression is made up of operator. Ans2: All expression do some
# operation like addition, multiplication, subtraction etc.
#
# 5.This assignment statements, like spam = 10. What is the difference
# between an expression and a statement?
#
# => spam=10 ,here we can call it is a statement (spam variable is used to
# store the value 10 using = operator expression)and = operator is
# expression
#
# 6.After running the following code, what does the variable bacon
# contain? bacon = 22 bacon + 1
#
# => bacon contain 22 because we increased the value of bacon but we did
# not assign the increased value of bacon
#
# 7.What should the values of the following two terms be? 'spam' +
# 'spamspam' 'spam' \* 3
#
# In \[1\]:
#
# 'spam' **+** 'spamspam'
#
# Out\[1\]:
#
# 'spamspamspam'
#
# In \[2\]:
#
# 'spam' **\*** 3
#
# Out\[2\]:
#
# 'spamspamspam'
#
# 8.Why is eggs a valid variable name while 100 is invalid?
#
# => Because 100 is a value and eggs is not a value
#
# 9.What three functions can be used to get the integer, floating-point
# number, or string version of a value?
#
# => Int(), float(), string()
#
# 10.Why does this expression cause an error? How can you fix it? 'I have
# eaten ' + 99 + ' burritos.'
#
# => because string and integer can not concatenate.
#
# In \[4\]:
#
# 'I have eaten ' **+** '99' **+** ' burritos.'
#
# Out\[4\]:
#
# 'I have eaten 99 burritos.'
