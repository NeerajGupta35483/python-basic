# %% [markdown]
# **
# 1.To what does a relative path refer?**
#
# Ans: A relative path refers to a location that is relative to a current
# directory
#
# **2.What does an absolute path start with your operating system?**
#
# Ans: An absolute path refers to the complete details needed to locate a
# file or folder, starting from the root element and ending with the other
# subdirectories. Absolute paths are used in websites and operating
# systems for locating files and folders. An absolute path is also known
# as an absolute pathname or full path.
#
# **3.What do the functions os.getcwd() and os.chdir() do?**
#
# Ans: os.getcwd() is used to check path of th current working directory
# os.chdir() is used to change the path from the present directory to
# target directory
#
# **4.What are the . and .. folders?**
#
# Ans: . refers the present directory
#
# .. refers the parent directory
#
# **5.In C:\\bacon\\eggs\\spam.txt, which part is the dir name, and which
# part is the base name?**
#
# C:\\bacon\\eggs\\spam.txt
#
# C:\\bacon\\eggs -> dir name
#
# spam.txt -> base name
#
# **6.What are the three “mode” arguments that can be passed to the open()
# function?**
#
# Ans: 'r','w','a'
#
# **7.What happens if an existing file is opened in write mode?**
#
# Ans: if an existing file is opened in write mode then if we write
# something than previous text from the file will be deleted
#
# **8.How do you tell the difference between read() and readlines()?**
#
# Ans: read() is used to read all the text from the file
#
# readlines() is used to read the only one line of text from the file
#
# **9.What data structure does a shelf value resemble?**
#
# Ans: dictionary does a shelf value resemble
